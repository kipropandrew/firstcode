# %% [markdown]
# ##Awsome this my first watson studio experience

# %% [markdown]
# **I love my country Kenya**

# %% [markdown]
# *Mountai Bongo in Mount Kenya Conservenacy*

# %% [markdown]
# |model|year |
# |prado|1980 |
# |mercedes|1954|
# |jeep |2021|
# |mazda|2020|
